# %% [markdown]
# #### Code to train models

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cd ../src
# Out:
# /home/theo/kaggle/foursquare/src

# %% [markdown]
# ## Imports

# %%
import os
import torch

os.environ['CUDA_VISIBLE_DEVICES'] = "1"
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 2080 Ti'

# %%
import os
import ast
import glob
import json
import torch
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from collections import Counter
from tqdm.notebook import tqdm
from numerize.numerize import numerize

# %%
from params import *

from data.preparation import prepare_train_data, prepare_triplet_data
from data.dataset import SingleDataset
from data.tokenization import get_tokenizer

from model_zoo.models import SingleTransformer

from utils.logger import Config
from utils.torch import load_model_weights
from utils.metrics import *

from inference.predict import predict
from inference.knn import *

# %% [markdown]
# ## Data

# %%
df = prepare_train_data(root=DATA_PATH)

# %%
folds = pd.read_csv(DATA_PATH + "folds_2.csv")[['id', 'fold']]
df = df.merge(folds, how="left", on="id").set_index("id")

# %%
FOLD = 0

# %%
df = df[df['fold'] == FOLD]

# %%
gt_matches = json.load(open(DATA_PATH + "gt.json", 'r'))

# %% [markdown]
# ## Exp

# %%
# EXP_FOLDER = LOG_PATH + "2022-05-18/2/"
# EXP_FOLDER = LOG_PATH + "2022-05-18/3/"  # 10 ep
# EXP_FOLDER = LOG_PATH + "2022-05-19/0/"  # 2 ep, triplets_v2
EXP_FOLDER = LOG_PATH + "2022-05-19/1/"  # 1 ep, triplets_v2, d=64

# %%
config = Config(json.load(open(EXP_FOLDER + "config.json", 'r')))

# %%
tokenizer = get_tokenizer(config.name)

# %%
dataset = SingleDataset(df, tokenizer, config.max_len)

# %%
weights = sorted(glob.glob(EXP_FOLDER + "*.pt"))

# %%
model = SingleTransformer(
    config.name,
    nb_layers=config.nb_layers,
    no_dropout=config.no_dropout,
    embed_dim=config.embed_dim,
    nb_features=config.nb_features,
).cuda()
model.zero_grad()

model = load_model_weights(model, weights[FOLD])
# Out:
#  -> Loading weights from ../logs/2022-05-19/1/xlm-roberta-base_0.pt

# %%
if os.path.exists(EXP_FOLDER + f"fts_val_{FOLD}.npy"):
    preds = np.load(EXP_FOLDER + f"fts_val_{FOLD}.npy")
else:
    preds = predict(model, dataset, config.data_config)
    np.save(EXP_FOLDER + f"fts_val_{FOLD}.npy", preds)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=35588.0), HTML(value='')))

# %% [markdown]
# ### Matches

# %%
for n_neighbors in [20, 30, 40, 50]:
    print(f'\n- -> n_neighbors={n_neighbors}\n')

    preds_matches = find_matches(preds, df, n_neighbors)
    found_prop, missed_nn = compute_found_prop(preds_matches, gt_matches)
    n_matches = sum([len(preds_matches[k]) - 1 for k in preds_matches])
    print(f' - Roberta :\t Found {found_prop * 100 :.2f}% of matches with {numerize(n_matches)} candidates.')

#     position_matches = json.load(open(OUT_PATH + f"knn_preds_{n_neighbors}_0.json", 'r'))
#     position_matches = json.load(open(OUT_PATH + f"dist_matches_{n_neighbors}_0.json", 'r'))
    position_matches = json.load(open(OUT_PATH + f"dist-phone-url_matches_{n_neighbors}_0.json", 'r'))

    found_prop, missed_pos = compute_found_prop(position_matches, gt_matches)
    n_matches = sum([len(position_matches[k]) - 1 for k in position_matches])
    print(f' - Position :\t Found {found_prop * 100 :.2f}% of matches with {numerize(n_matches)} candidates.')

    merged_matches = {k : list(set(position_matches[k] + preds_matches[k])) for k in preds_matches}
    found_prop, missed = compute_found_prop(merged_matches, gt_matches)
    n_matches = sum([len(merged_matches[k]) - 1 for k in merged_matches])
    print(f' - Merged :\t found {found_prop * 100 :.2f}% of matches with {numerize(n_matches)} candidates.')
# Out:
# - -> n_neighbors=20
#
#  - Roberta :	 Found 39.98% of matches with 10.82M candidates.
#  - Position :	 Found 81.25% of matches with 11.07M candidates.
#  - Merged :	 found 87.41% of matches with 21.62M candidates.
#
# - -> n_neighbors=30
#
#  - Roberta :	 Found 42.77% of matches with 16.51M candidates.
#  - Position :	 Found 83.96% of matches with 16.51M candidates.
#  - Merged :	 found 89.69% of matches with 32.69M candidates.
#
# - -> n_neighbors=40

# %% [markdown]
# - -> n_neighbors=20
#
#  - Roberta :	 Found 56.88% of matches with 10.82M candidates.
#  - Position :	 Found 81.25% of matches with 11.07M candidates.
#  - Merged :	 found 90.59% of matches with 21.52M candidates.
#
# - -> n_neighbors=30
#
#  - Roberta :	 Found 59.69% of matches with 16.51M candidates.
#  - Position :	 Found 83.96% of matches with 16.51M candidates.
#  - Merged :	 found 92.44% of matches with 32.57M candidates.
#
# - -> n_neighbors=40
#
#  - Roberta :	 Found 61.66% of matches with 22.21M candidates.
#  - Position :	 Found 85.63% of matches with 21.87M candidates.
#  - Merged :	 found 93.53% of matches with 43.56M candidates.
#
# - -> n_neighbors=50
#
#  - Roberta :	 Found 63.20% of matches with 27.9M candidates.
#  - Position :	 Found 86.83% of matches with 27.13M candidates.
#  - Merged :	 found 94.30% of matches with 54.47M candidates.

# %%
for i in range(100):
    if len(gt_matches[df.index[i]]) <= 1:
        continue
    if not len(df.loc[list(missed[i])]):
        continue

    print('Query')
    display(df.loc[[df.index[i]]])

    print('Target')
    display(df.loc[gt_matches[df.index[i]]])

    print('Missed')
    display(df.loc[list(missed[i])])

#     print('Preds')
#     display(df.loc[preds_matches[df.index[i]]].head(5))

#     break
    print('-' * 50)
# Out:
# Query
#                              name   latitude  longitude  \
# id
# E_0005d223c299ab  гб 26костюшко 2  59.848975  30.294264
#
#                                               address country url phone  \
# id
# E_0005d223c299ab  Ул. Костюшко 2, Санкт-Петербург, RU      RU
#
#                  categories point_of_interest   clust  fold
# id
# E_0005d223c299ab  Hospitals  P_b9ff4f6a365ad0  205706     0
# Target
#                                                   name   latitude  longitude  \
# id
# E_13bbf0a27cfb9a  Хирургическое Отделение. Больница 26  59.851817  30.298295
# E_e7f5381a2425e3                             Больничка  59.848934  30.295753
# E_9ab5a9ee6069ab                             Палата 18  59.849037  30.297071
# E_eb824f0b14ac67                Городская больница №26  59.849424  30.295438
# E_811d75955cb441                      Палата 1. 4 этаж  59.849085  30.294058
# E_93d80b2c50d8fa                Городская больница №26  59.838110  30.237221
# E_3db8de706c6caa                       Палата Тусэ N 5  59.848853  30.294709
# E_e9d3ce80ac24ec                           Кабинет УЗИ  59.849300  30.294802
# E_1603a71e9bcdfc                              Палата 9  59.848981  30.295432
# E_ea2a92a9306798                Городская больница №26  59.904487  30.342419
# E_0005d223c299ab                       гб 26костюшко 2  59.848975  30.294264
# E_8da9e740f28d61                              Палата 3  59.849579  30.294830
#
#                                                             address country  \
# id
# E_13bbf0a27cfb9a                                                 RU      RU
# E_e7f5381a2425e3                                                 RU      RU
# E_9ab5a9ee6069ab                                                 RU      RU
# E_eb824f0b14ac67  ул. Костюшко, 2, Санкт-Петербург, Санкт-Петерб...      RU
# E_811d75955cb441                                                 RU      RU
# E_93d80b2c50d8fa                ул. Костюшко, 2, St.-Petersburg, RU      RU
# E_3db8de706c6caa                                                 RU      RU
# E_e9d3ce80ac24ec                                                 RU      RU
# E_1603a71e9bcdfc                                                 RU      RU
# E_ea2a92a9306798                ул. Костюшко, 2, St.-Petersburg, RU      RU
# E_0005d223c299ab                Ул. Костюшко 2, Санкт-Петербург, RU      RU
# E_8da9e740f28d61             Костюшко Ул., Д.2, Санкт-Петербург, RU      RU
#
#                             url         phone categories point_of_interest  \
# id
# E_13bbf0a27cfb9a                               Hospitals  P_b9ff4f6a365ad0
# E_e7f5381a2425e3                               Hospitals  P_b9ff4f6a365ad0
# E_9ab5a9ee6069ab                               Hospitals  P_b9ff4f6a365ad0
# E_eb824f0b14ac67  hospital26.ru    8124151888  Hospitals  P_b9ff4f6a365ad0
# E_811d75955cb441                               Hospitals  P_b9ff4f6a365ad0
# E_93d80b2c50d8fa                 +78124151888  Hospitals  P_b9ff4f6a365ad0
# E_3db8de706c6caa                               Hospitals  P_b9ff4f6a365ad0
# E_e9d3ce80ac24ec                                          P_b9ff4f6a365ad0
# E_1603a71e9bcdfc                               Hospitals  P_b9ff4f6a365ad0
# E_ea2a92a9306798                 +78124151888  Hospitals  P_b9ff4f6a365ad0
# E_0005d223c299ab                               Hospitals  P_b9ff4f6a365ad0
# E_8da9e740f28d61                               Hospitals  P_b9ff4f6a365ad0
#
#                    clust  fold
# id
# E_13bbf0a27cfb9a  205706     0
# E_e7f5381a2425e3  205706     0
# E_9ab5a9ee6069ab  205706     0
# E_eb824f0b14ac67  205706     0
# E_811d75955cb441  205706     0
# E_93d80b2c50d8fa  205706     0
# E_3db8de706c6caa  205706     0
# E_e9d3ce80ac24ec  205706     0
# E_1603a71e9bcdfc  205706     0
# E_ea2a92a9306798  205706     0
# E_0005d223c299ab  205706     0
# E_8da9e740f28d61  205706     0
# Missed
#                                     name   latitude  longitude  \
# id
# E_ea2a92a9306798  Городская больница №26  59.904487  30.342419
# E_93d80b2c50d8fa  Городская больница №26  59.838110  30.237221
#
#                                               address country url  \
# id
# E_ea2a92a9306798  ул. Костюшко, 2, St.-Petersburg, RU      RU
# E_93d80b2c50d8fa  ул. Костюшко, 2, St.-Petersburg, RU      RU
#
#                          phone categories point_of_interest   clust  fold
# id
# E_ea2a92a9306798  +78124151888  Hospitals  P_b9ff4f6a365ad0  205706     0
# E_93d80b2c50d8fa  +78124151888  Hospitals  P_b9ff4f6a365ad0  205706     0
# --------------------------------------------------
# Query
#                           name   latitude  longitude  \
# id
# E_000ac5c1692f17  Costa Coffee  55.633228  37.633801
#
#                                        address country url phone  \
# id
# E_000ac5c1692f17  Каширское ш., 26, Москва, RU      RU
#
#                     categories point_of_interest   clust  fold
# id
# E_000ac5c1692f17  Coffee Shops  P_cb130155215509  178484     0
# Target
#                           name   latitude  longitude  \
# id
# E_02123b385ee6c1  Costa coffee  55.653243  37.646748
# E_000ac5c1692f17  Costa Coffee  55.633228  37.633801
#
#                                                 address country  \
# id
# E_02123b385ee6c1  ТРК «Москворечье», Москва, Россия, RU      RU
# E_000ac5c1692f17           Каширское ш., 26, Москва, RU      RU
#
#                              url phone    categories point_of_interest  \
# id
# E_02123b385ee6c1  costacoffee.ru        Coffee Shops  P_cb130155215509
# E_000ac5c1692f17                        Coffee Shops  P_cb130155215509
#
#                    clust  fold
# id
# E_02123b385ee6c1  178484     0
# E_000ac5c1692f17  178484     0
# Missed
#                           name   latitude  longitude  \
# id
# E_02123b385ee6c1  Costa coffee  55.653243  37.646748
#
#                                                 address country  \
# id
# E_02123b385ee6c1  ТРК «Москворечье», Москва, Россия, RU      RU
#
#                              url phone    categories point_of_interest  \
# id
# E_02123b385ee6c1  costacoffee.ru        Coffee Shops  P_cb130155215509
#
#                    clust  fold
# id
# E_02123b385ee6c1  178484     0
# --------------------------------------------------
# Query
#                             name   latitude  longitude address country url  \
# id
# E_000b6fee493351  Atlantic Ocean  33.502066 -79.065192      US      US
#
#                  phone categories point_of_interest   clust  fold
# id
# E_000b6fee493351          Beaches  P_dc6fc88a91a408  116314     0
# Target
#                                                    name   latitude  longitude  \
# id
# E_6727ec3ecf88ae                     The atlantic Ocean  47.543993 -52.575458
# E_000b6fee493351                         Atlantic Ocean  33.502066 -79.065192
# E_fb179fb773551a                         Atlantic Ocean  39.532596 -74.262788
# E_f74c8a0744d3f9                         Atlantic Ocean  39.201227 -14.895984
# E_76cbba4a082131  on a boat somewhere In atlantic ocean  33.778001 -78.536479
# E_d6d2369199339e          где то в атлантическом океане  27.997034 -16.657917
# E_2f5181918a188c                         Atlantic Ocean  28.066065 -16.729744
# E_da4966c09d1280                        Где то в океане  28.046823 -16.764508
# E_afedc006ea1570          Somewhere over Atlantic Ocean  60.785767 -39.674180
# E_f716e71e181501                    В Атлантике На Яхте  28.023055 -16.573253
#
#                                     address country url phone  \
# id
# E_6727ec3ecf88ae                         CA      CA
# E_000b6fee493351                         US      US
# E_fb179fb773551a  Beach Haven, NJ, 08008 US      US
# E_f74c8a0744d3f9   Trazo, Galiçya, 15687 ES      ES
# E_76cbba4a082131                         US      US
# E_d6d2369199339e                         ES      ES
# E_2f5181918a188c                         ES      ES
# E_da4966c09d1280                         ES      ES
# E_afedc006ea1570                         GL      GL
# E_f716e71e181501                         ES      ES
#
#                             categories point_of_interest   clust  fold
# id
# E_6727ec3ecf88ae                        P_dc6fc88a91a408  116314     0
# E_000b6fee493351               Beaches  P_dc6fc88a91a408  116314     0
# E_fb179fb773551a  Other Great Outdoors  P_dc6fc88a91a408  116314     0
# E_f74c8a0744d3f9                        P_dc6fc88a91a408  116314     0
# E_76cbba4a082131  Other Great Outdoors  P_dc6fc88a91a408  116314     0
# E_d6d2369199339e                        P_dc6fc88a91a408  116314     0
# E_2f5181918a188c  Other Great Outdoors  P_dc6fc88a91a408  116314     0
# E_da4966c09d1280         Fishing Spots  P_dc6fc88a91a408  116314     0
# E_afedc006ea1570                        P_dc6fc88a91a408  116314     0
# E_f716e71e181501                        P_dc6fc88a91a408  116314     0
# Missed
#                                            name   latitude  longitude address  \
# id
# E_6727ec3ecf88ae             The atlantic Ocean  47.543993 -52.575458      CA
# E_d6d2369199339e  где то в атлантическом океане  27.997034 -16.657917      ES
# E_f716e71e181501            В Атлантике На Яхте  28.023055 -16.573253      ES
# E_da4966c09d1280                Где то в океане  28.046823 -16.764508      ES
#
#                  country url phone     categories point_of_interest   clust  \
# id
# E_6727ec3ecf88ae      CA                           P_dc6fc88a91a408  116314
# E_d6d2369199339e      ES                           P_dc6fc88a91a408  116314
# E_f716e71e181501      ES                           P_dc6fc88a91a408  116314
# E_da4966c09d1280      ES            Fishing Spots  P_dc6fc88a91a408  116314
#
#                   fold
# id
# E_6727ec3ecf88ae     0
# E_d6d2369199339e     0
# E_f716e71e181501     0
# E_da4966c09d1280     0
# --------------------------------------------------
# Query
#                    name   latitude  longitude address country url phone  \
# id
# E_000c1e53567646  Esbaş  38.336512  27.133751      TR      TR
#
#                         categories point_of_interest   clust  fold
# id
# E_000c1e53567646  Coworking Spaces  P_9ef6227fc7603a  159240     0
# Target
#                                     name   latitude  longitude  \
# id
# E_df02c68e9725ef  Gaziemir Serbest Bölge  38.335986  27.133831
# E_55709c6beefb17         Agean Free Zone  38.337053  27.133114
# E_000c1e53567646                   Esbaş  38.336512  27.133751
# E_74713f5c0acbe5     Ege Serbest Bölgesi  38.336693  27.129885
# E_c84e5082be0ad6       Ege serbest bölge  38.335944  27.123388
#
#                                                          address country  \
# id
# E_df02c68e9725ef                                       İzmir, TR      TR
# E_55709c6beefb17                                              TR      TR
# E_000c1e53567646                                              TR      TR
# E_74713f5c0acbe5  Akçay Cad. No:144/1, Gaziemir, İzmir, 35410 TR      TR
# E_c84e5082be0ad6                                              TR      TR
#
#                            url       phone          categories  \
# id
# E_df02c68e9725ef
# E_55709c6beefb17
# E_000c1e53567646                              Coworking Spaces
# E_74713f5c0acbe5  esbas.com.tr  2322513851  Industrial Estates
# E_c84e5082be0ad6                                     Factories
#
#                  point_of_interest   clust  fold
# id
# E_df02c68e9725ef  P_9ef6227fc7603a  159240     0
# E_55709c6beefb17  P_9ef6227fc7603a  159240     0
# E_000c1e53567646  P_9ef6227fc7603a  159240     0
# E_74713f5c0acbe5  P_9ef6227fc7603a  159240     0
# E_c84e5082be0ad6  P_9ef6227fc7603a  159240     0
# Missed
#                                name   latitude  longitude address country url  \
# id
# E_c84e5082be0ad6  Ege serbest bölge  38.335944  27.123388      TR      TR
#
#                  phone categories point_of_interest   clust  fold
# id
# E_c84e5082be0ad6        Factories  P_9ef6227fc7603a  159240     0
# --------------------------------------------------
